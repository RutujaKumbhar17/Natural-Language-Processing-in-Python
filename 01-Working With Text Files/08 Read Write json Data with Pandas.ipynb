# %%
import json

# %%
import pandas as pd
url = 'https://github.com/laxmimerit/All-CSV-ML-DATA-Files-Download/raw/master/Data%20-%20Multiple%20Worksheets.xlsx'
df = pd.read_excel(url, sheet_name = 'Data 1')
df
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
df.to_json('data/output.json')

# %%
df.to_json('data/output.json',orient ='records') #this gives each record separatey in curly braces

# %%
df.to_json('data/output1.json',orient ='records',lines='True' ) #to show the records in different lines

# %%
#read the json file
d1=json.load(open ('data/output.json'))

# %%
d1[2]
# Out:
# {'First Name': 'Judy',
#  'Last Name': 'Day',
#  'City': 'Los Angeles',
#  'Gender': 'F'}

# %%
pd.DataFrame(d1)
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
d1=pd.read_json('data/output.json')
d1
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
d2=pd.read_json('data/output1.json',lines=True) #Need to write this coz content in output1 is line wise
d2
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F
